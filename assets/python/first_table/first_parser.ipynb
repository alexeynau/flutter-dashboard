# %%
import pandas as pd
import numpy as np
data = pd.read_excel("Приложение 1.xlsx")
data
# Out:
#     Макропараметры БП 2022-2026            Unnamed: 1  \
# 0                        Курс $  Цена Brent,\n$/барр.
# 1                           NaN                   NaN
# 2                         71.96             71.082776
# 3                        76.166                   NaN
# 4                       75.0141                   NaN
# ..                          ...                   ...
# 200                         NaN                   NaN
# 201                         NaN                   NaN
# 202                         NaN                   NaN
# 203                         NaN                   NaN
# 204                         NaN                   NaN
#
#                            Unnamed: 2                         Unnamed: 3  \
# 0    Spread (Корректировка),\n$/барр.  Freight (Корректировка),\n$/барр.
# 1                                 NaN                                NaN
# 2                                -2.2                          -1.132817
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 200                               NaN                                NaN
# 201                               NaN                                NaN
# 202                               NaN                                NaN
# 203                               NaN                                NaN
# 204                               NaN                                NaN
#
#                    Unnamed: 4                          Unnamed: 5  \
# 0    Дисконт/Премия,\n$/барр.  Escalation/De-escalation,\n$/барр.
# 1                         NaN                                 NaN
# 2                           0                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# ..                        ...                                 ...
# 200                       NaN                                 NaN
# 201                       NaN                                 NaN
# 202                       NaN                                 NaN
# 203                       NaN                                 NaN
# 204                       NaN                                 NaN
#
#                              Unnamed: 6               Unnamed: 7  \
# 0    Расчетная цена на границе, $/барр.  Экспортная пошлина, $/т
# 1                                   NaN                      NaN
# 2                             67.749959                     41.7
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
# ..                                  ...                      ...
# 200                                 NaN                      NaN
# 201                                 NaN                      NaN
# 202                                 NaN                      NaN
# 203                                 NaN                      NaN
# 204                                 NaN                      NaN
#
#                                    Unnamed: 8     Покупатель  ...  \
# 0    Коммерческие (за искл. Freight), $/барр.            NaN  ...
# 1                                         NaN     Компания 1  ...
# 2                                    5.877592     Customer 1  ...
# 3                                         NaN     Customer 1  ...
# 4                                         NaN     Customer 1  ...
# ..                                        ...            ...  ...
# 200                                       NaN            NaN  ...
# 201                                       NaN          Итого  ...
# 202                                       NaN  с учетом доли  ...
# 203                                       NaN            NaN  ...
# 204                                       NaN            NaN  ...
#
#                                           Unnamed: 107  \
# 0    Макропараметры (brent/ discount/ escalation) м...
# 1                                                  NaN
# 2                                           222.920623
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
#
#                          Unnamed: 108        Unnamed: 109  \
# 0    Макропараметры (spread) млн руб.  Freight,\nмлн руб.
# 1                                 NaN                 NaN
# 2                         1646.819607          -12.898963
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
# ..                                ...                 ...
# 200                               NaN                 NaN
# 201                               NaN                 NaN
# 202                               NaN                 NaN
# 203                               NaN                 NaN
# 204                               NaN                 NaN
#
#                                  Unnamed: 110                  Unnamed: 111  \
# 0    Коммерческие за искл. Freight,\nмлн руб.  Экспортная пошлина, млн руб.
# 1                                         NaN                           NaN
# 2                                  -22.040238                     37.215639
# 3                                         NaN                             0
# 4                                         NaN                             0
# ..                                        ...                           ...
# 200                                       NaN                           NaN
# 201                                       NaN                     37.215639
# 202                                       NaN                     18.979976
# 203                                       NaN                           NaN
# 204                                       NaN                           NaN
#
#                                       Unnamed: 112  \
# 0    Курсовые разницы (отгрузка / оплата)\nмлн руб
# 1                                              NaN
# 2                                       -20.498265
# 3                                                0
# 4                                                0
# ..                                             ...
# 200                                            NaN
# 201                                     -20.498265
# 202                                     -10.454115
# 203                                            NaN
# 204                                            NaN
#
#                    Unnamed: 113  \
# 0    откл НДПИ (макропараметры)
# 1                           NaN
# 2                   -286.448588
# 3                             0
# 4                             0
# ..                          ...
# 200                         NaN
# 201                         NaN
# 202                         NaN
# 203                         NaN
# 204                         NaN
#
#                                           Unnamed: 114  \
# 0    откл НДПИ уплач от расч НДПИ (курс оплаты)\nмл...
# 1                                                  NaN
# 2                                            26.226191
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
#
#                                           Unnamed: 115  Unnamed: 116
# 0    откл НДПИ (Argus) и НДПИ (Plats Urals Med), мл...        Эффект
# 1                                                  NaN           NaN
# 2                                            89.742174   4898.494195
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 200                                                NaN           NaN
# 201                                                NaN           NaN
# 202                                                NaN           NaN
# 203                                                NaN           NaN
# 204                                                NaN           NaN
#
# [205 rows x 117 columns]

# %%
import urllib
import requests
from bs4 import BeautifulSoup as bs
import urllib.request as urllib2

from urllib.request import Request, urlopen
from urllib.error import HTTPError
from urllib.request import urlopen
url = 'https://ru.investing.com/commodities/brent-wti-crude-spread-futures-historical-data'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})

web_byte = urlopen(req).read()

webpage = web_byte.decode('utf-8')
webpage
# Out:
# '<!DOCTYPE html><html lang="ru" dir="ltr" class="html"><head><script>\n                window.geo_country_state = \'RU_SPE\';\n                window.geo_country = \'RU\';\n                window.geo_state = \'SPE\';\n                function appendOneTrust() {\n                    return new Promise((resolve, reject) => {\n                        const script = document.createElement(\'script\');\n                        script.src = \'https://cookie-cdn.cookiepro.com/scripttemplates/otSDKStub.js\';\n                        script.dataset.domainScript = \'265d5ac2-7d0c-4675-bf4d-421a61fb482e\';\n                        script.onload = resolve;\n                        script.onerror = reject;\n                        document.body.appendChild(script);\n                    });\n                }\n            </script>\n<script>\n        var isRuGeoLocation = window.geo_country && window.geo_country.toLowerCase() === "ru";\n        var ads_script = document.createElement(\'script\');\n        ads_script.src = isRuGeoLocation ? \'https://yandex.ru/ads/system/context.js\' : \'//securepubads.g.doubleclick.net/tag/js/gpt.js\';\n        ads_script.async = true;\n        document.head.appendChild(ads_script);\n    \n             \n            </script><meta charSet="utf-8" /><meta name="viewport" content="initial-scale=1.0, width=device-width" /><link rel="canonical" href="https://ru.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="x-default" href="https://www.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="en-us" href="https://www.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="he-il" href="https://il.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="ar" href="https://sa.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="es" href="https://es.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="fr" href="https://fr.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="zh-cn" href="https://cn.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="ru" href="https://ru.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="de" href="https://de.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="it" href="https://it.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="tr-tr" href="https://tr.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="ja-jp" href="https://jp.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="pt" href="https://br.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="sv-se" href="https://se.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="el-gr" href="https://gr.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="pl-pl" href="https://pl.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="nl" href="https://nl.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="fi-fi" href="https://fi.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="ko-kr" href="https://kr.investing.com/commodities/brent-wti-crude-spread-futures-historical-data" /><link rel="alternate" hreflang="es ...

# %%
soup = bs(webpage, "html.parser")
quotes = soup.find_all('td', class_='datatable_cell__LJp3C datatable_cell--align-end__qgxDQ datatable_cell--up__hIuZF text-right text-sm font-normal leading-5 align-middle min-w-[77px] text-[#007C32]')


for quote in quotes:
    print(quote.text)
# Out:
# -3,24
# -3,67
# -3,85
# -3,87
# -3,91
# -3,90
# -3,77
# -3,81
# -3,76
# -3,23
# -4,23
# -4,32
# -4,61
# -4,31
# -4,32

# %%
data
data.columns = data.iloc[0]
data = data.drop(0, axis = 0)

# %%
data
# Out:
# 0     Курс $ Цена Brent,\n$/барр. Spread (Корректировка),\n$/барр.  \
# 1        NaN                  NaN                              NaN
# 2      71.96            71.082776                             -2.2
# 3     76.166                  NaN                              NaN
# 4    75.0141                  NaN                              NaN
# 5    75.7527                  NaN                              NaN
# ..       ...                  ...                              ...
# 200      NaN                  NaN                              NaN
# 201      NaN                  NaN                              NaN
# 202      NaN                  NaN                              NaN
# 203      NaN                  NaN                              NaN
# 204      NaN                  NaN                              NaN
#
# 0   Freight (Корректировка),\n$/барр. Дисконт/Премия,\n$/барр.  \
# 1                                 NaN                      NaN
# 2                           -1.132817                        0
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# 5                                 NaN                      NaN
# ..                                ...                      ...
# 200                               NaN                      NaN
# 201                               NaN                      NaN
# 202                               NaN                      NaN
# 203                               NaN                      NaN
# 204                               NaN                      NaN
#
# 0   Escalation/De-escalation,\n$/барр. Расчетная цена на границе, $/барр.  \
# 1                                  NaN                                NaN
# 2                                  NaN                          67.749959
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# 5                                  NaN                                NaN
# ..                                 ...                                ...
# 200                                NaN                                NaN
# 201                                NaN                                NaN
# 202                                NaN                                NaN
# 203                                NaN                                NaN
# 204                                NaN                                NaN
#
# 0   Экспортная пошлина, $/т Коммерческие (за искл. Freight), $/барр.  \
# 1                       NaN                                      NaN
# 2                      41.7                                 5.877592
# 3                       NaN                                      NaN
# 4                       NaN                                      NaN
# 5                       NaN                                      NaN
# ..                      ...                                      ...
# 200                     NaN                                      NaN
# 201                     NaN                                      NaN
# 202                     NaN                                      NaN
# 203                     NaN                                      NaN
# 204                     NaN                                      NaN
#
# 0              NaN  ... Макропараметры (brent/ discount/ escalation) млн руб.  \
# 1       Компания 1  ...                                                NaN
# 2       Customer 1  ...                                         222.920623
# 3       Customer 1  ...                                                NaN
# 4       Customer 1  ...                                                NaN
# 5       Customer 1  ...                                                NaN
# ..             ...  ...                                                ...
# 200            NaN  ...                                                NaN
# 201          Итого  ...                                                NaN
# 202  с учетом доли  ...                                                NaN
# 203            NaN  ...                                                NaN
# 204            NaN  ...                                                NaN
#
# 0   Макропараметры (spread) млн руб. Freight,\nмлн руб.  \
# 1                                NaN                NaN
# 2                        1646.819607         -12.898963
# 3                                NaN                NaN
# 4                                NaN                NaN
# 5                                NaN                NaN
# ..                               ...                ...
# 200                              NaN                NaN
# 201                              NaN                NaN
# 202                              NaN                NaN
# 203                              NaN                NaN
# 204                              NaN                NaN
#
# 0   Коммерческие за искл. Freight,\nмлн руб. Экспортная пошлина, млн руб.  \
# 1                                        NaN                          NaN
# 2                                 -22.040238                    37.215639
# 3                                        NaN                            0
# 4                                        NaN                            0
# 5                                        NaN                            0
# ..                                       ...                          ...
# 200                                      NaN                          NaN
# 201                                      NaN                    37.215639
# 202                                      NaN                    18.979976
# 203                                      NaN                          NaN
# 204                                      NaN                          NaN
#
# 0   Курсовые разницы (отгрузка / оплата)\nмлн руб  откл НДПИ (макропараметры)  \
# 1                                             NaN                         NaN
# 2                                      -20.498265                 -286.448588
# 3                                               0                           0
# 4                                               0                           0
# 5                                               0                           0
# ..                                            ...                         ...
# 200                                           NaN                         NaN
# 201                                    -20.498265                         NaN
# 202                                    -10.454115                         NaN
# 203                                           NaN                         NaN
# 204                                           NaN                         NaN
#
# 0   откл НДПИ уплач от расч НДПИ (курс оплаты)\nмлн руб  \
# 1                                                  NaN
# 2                                            26.226191
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 200                                                NaN
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
#
# 0   откл НДПИ (Argus) и НДПИ (Plats Urals Med), млн руб.       Эффект
# 1                                                  NaN            NaN
# 2                                            89.742174    4898.494195
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# 5                                                  NaN            NaN
# ..                                                 ...            ...
# 200                                                NaN            NaN
# 201                                                NaN            NaN
# 202                                                NaN            NaN
# 203                                                NaN            NaN
# 204                                                NaN            NaN
#
# [204 rows x 117 columns]
